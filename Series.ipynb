# %%
import pandas as pd
import numpy as np

# %%
lst = ["Mustufa","Ahmed","Ibrahim"]
index = ["a","b","c"]
dic = {"1":"Mustufa","2":"Laiba", "3":"Mujtuba"}
pd.Series(lst, index = index)
a = np.array([1,2,3,4])
pd.Series(dic)
pd.Series(a)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64
